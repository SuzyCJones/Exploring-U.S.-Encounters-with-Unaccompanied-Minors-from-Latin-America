# %% [markdown]
# # See how Encounter Type and Encounter Count relate to each other using a Chi Square

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Encounters = pd.read_excel("/Users/suzejones/Downloads/Finalsbo-encounters-fy20-fy23-apr .xlsx")

# %%
Encounters.head()
# Out:
#   Fiscal Year Month Grouping Month (abbv)                   Component  \
# 0        2020           FYTD          OCT  Office of Field Operations
# 1        2020           FYTD          OCT  Office of Field Operations
# 2        2020           FYTD          OCT  Office of Field Operations
# 3        2020           FYTD          OCT  Office of Field Operations
# 4        2020           FYTD          OCT  Office of Field Operations
#
#           Demographic Citizenship Grouping Title of Authority Encounter Type  \
# 0  Accompanied Minors          El Salvador            Title 8  Inadmissibles
# 1  Accompanied Minors            Guatemala            Title 8  Inadmissibles
# 2  Accompanied Minors               Mexico            Title 8  Inadmissibles
# 3  Accompanied Minors                Other            Title 8  Inadmissibles
# 4                FMUA          El Salvador            Title 8  Inadmissibles
#
#    Encounter Count
# 0                2
# 1                1
# 2               91
# ...

# %%
Encounters.columns
# Out:
# Index(['Fiscal Year', 'Month Grouping', 'Month (abbv)', 'Component',
#        'Demographic', 'Citizenship Grouping', 'Title of Authority',
#        'Encounter Type', 'Encounter Count'],
#       dtype='object')

# %%
from scipy import stats

# %%
Encounters_crosstab = pd.crosstab(Encounters['Encounter Type'], Encounters['Encounter Count'])

# %%
Encounters_crosstab
# Out:
# Encounter Count  0      1      2      3      4      5      6      7      \
# Encounter Type
# Apprehensions        0      2      3      0      2      2      1      1
# Expulsions           0     52     31     18     15      5      8     11
# Inadmissibles       18     44     31     15     22     10     18     13
#
# Encounter Count  8      9      ...  59725  60046  60478  61220  67024  69889  \
# Encounter Type                 ...
# Apprehensions        3      1  ...      1      0      0      0      0      1
# Expulsions           8     14  ...      0      1      1      1      1      0
# Inadmissibles       12     10  ...      0      0      0      0      0      0
#
# Encounter Count  73562  79048  80383  97582
# Encounter Type
# Apprehensions        0      1      1      1
# Expulsions           1      0      0      0
# Inadmissibles        0      0      0      0
#
# [3 rows x 1191 columns]

# %% [markdown]
# # The Encounter Count and the Encounter Type together are a bit of a mess because of the amount of data to compare
