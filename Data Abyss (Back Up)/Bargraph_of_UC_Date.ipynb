# %%
Import Data:

# %%
install.packages("ggplot2")
install.packages("datasets")
install.packages("readxl") 
install.packages("dplyr") 
install.packages("PerformanceAnalytics")
install.packages("corrplot")
install.packages("gapminder")
install.packages("gridextra")
install.packages("Ecdat")
install.packages("corpcor")
install.packages("GPArotation")
install.packages("psych")
install.packages("IDPmisc")
install.packages("lattice") 
install.packages("treetop")
install.packages("scales")
install.packages("rcompanion")
install.packages("gmodels")
install.packages("car")
install.packages("caret")
install.packages("gvlma")
install.packages("predictmeans")
install.packages("caret")
install.packages("magrittr")
install.packages("tidyr")
install.packages("lmtest")
install.packages("popbio")
install.packages("e1071")
install.packages("data.table")
install.packages("effects")
install.packages("multcomp")
install.packages("mvnormtest")
# Out:
# The downloaded binary packages are in
# 	/var/folders/q_/vv8mn9pn63l7m3ps3k_2tqdm0000gn/T//RtmpiVFkb8/downloaded_packages
# Warning message:
# “package ‘datasets’ is a base package, and should not be updated”
# The downloaded binary packages are in
# 	/var/folders/q_/vv8mn9pn63l7m3ps3k_2tqdm0000gn/T//RtmpiVFkb8/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/q_/vv8mn9pn63l7m3ps3k_2tqdm0000gn/T//RtmpiVFkb8/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/q_/vv8mn9pn63l7m3ps3k_2tqdm0000gn/T//RtmpiVFkb8/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/q_/vv8mn9pn63l7m3ps3k_2tqdm0000gn/T//RtmpiVFkb8/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/q_/vv8mn9pn63l7m3ps3k_2tqdm0000gn/T//RtmpiVFkb8/downloaded_packages
# Warning message:
# “package ‘gridextra’ is not available for this version of R
#
# ...

# %% [markdown]
# ## Import Data

# %%
BPEncounters = read.csv("/Users/suzejones/Downloads/sbo-encounters-fy19-fy22.csv")

# %% [markdown]
# ## Wrangle Data

# %%
library("tidyr")

# %%
BPEncounters1 <- unite(BPEncounters, Date, Month..abbv., Fiscal.Year, sep = " ")

# %%
names(BPEncounters1)[names(BPEncounters1) == "Citizenship.Grouping"] <- "Citizenship"

# %%
names(BPEncounters1)[names(BPEncounters1) == "Title.of.Authority"] <- "Law.Enforced"

# %%
BPEncounters1 <- BPEncounters1[, -which(names(BPEncounters1) == "Month.Grouping")]

# %%
head(BPEncounters1)
# Out:
#   Date     Component                  Demographic        Citizenship
# 1 AUG 2019 Office of Field Operations Accompanied Minors Guatemala
# 2 DEC 2019 U.S. Border Patrol         FMUA               Honduras
# 3 SEP 2021 Office of Field Operations Single Adults      Other
# 4 SEP 2021 Office of Field Operations Single Adults      Guatemala
# 5 JUN 2019 Office of Field Operations Single Adults      Honduras
# 6 OCT 2019 Office of Field Operations UC / Single Minors Guatemala
#   Law.Enforced Encounter.Type Encounter.Count
# 1 Title 8      Inadmissibles     0
# 2 Title 8      Apprehensions  9584
# 3 Title 8      Inadmissibles  1108
# 4 Title 8      Inadmissibles    14
# 5 Title 8      Inadmissibles    87
# 6 Title 8      Inadmissibles   121

# %%
library ("ggplot2")

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
subset_BPEncounters1 <- filter(BPEncounters1, Demographic == "UC / Single Minors")

# %%
print(subset_BPEncounters1)
# Out:
#         Date                  Component        Demographic Citizenship
# 1   OCT 2019 Office of Field Operations UC / Single Minors   Guatemala
# 2   FEB 2019 Office of Field Operations UC / Single Minors    Honduras
# 3   JUN 2019 Office of Field Operations UC / Single Minors El Salvador
# 4   OCT 2021         U.S. Border Patrol UC / Single Minors    Honduras
# 5   AUG 2019 Office of Field Operations UC / Single Minors       Other
# 6   MAR 2019 Office of Field Operations UC / Single Minors El Salvador
# 7   OCT 2021 Office of Field Operations UC / Single Minors    Honduras
# 8   MAR 2021 Office of Field Operations UC / Single Minors   Guatemala
# 9   AUG 2020 Office of Field Operations UC / Single Minors      Mexico
# 10  OCT 2021 Office of Field Operations UC / Single Minors   Guatemala
# 11  MAY 2021         U.S. Border Patrol UC / Single Minors      Mexico
# 12  JAN 2019         U.S. Border Patrol UC / Single Minors El Salvador
# ...

# %%
BPEncounters_Date_UCM <- ggplot(subset_BPEncounters1, aes(x = Encounter.Count, y = Date))

# %%
BPEncountersCountPlot <- BPEncounters_Date_UCM + geom_bar(stat = "sum", fill = "steelblue")

# %%
BPEncountersCountPlot
# Out:
# plot without title

# %% [markdown]
# ## Conclusion: The count of unaccompanied minors bar graph mirrors the total count of encounters at the
# ## border for the most part.
